# %%
import pandas as pd

# %%
df=pd.read_csv("ElectricCarData_Norm (1).csv")
df.head()
# Out:
#          Brand                          Model     Accel  TopSpeed   Range  \
# 0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h  270 km
# 2    Polestar                               2   4.7 sec  210 km/h  400 km
# 3         BMW                            iX3    6.8 sec  180 km/h  360 km
# 4       Honda                              e    9.5 sec  145 km/h  170 km
#
#   Efficiency FastCharge              RapidCharge        PowerTrain  \
# 0  161 Wh/km   940 km/h  Rapid charging possible   All Wheel Drive
# 1  167 Wh/km   250 km/h  Rapid charging possible  Rear Wheel Drive
# 2  181 Wh/km   620 km/h  Rapid charging possible   All Wheel Drive
# 3  206 Wh/km   560 km/h  Rapid charging possible  Rear Wheel Drive
# 4  168 Wh/km   190 km/h  Rapid charging possible  Rear Wheel Drive
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
df.head()
# Out:
#          Brand                          Model     Accel  TopSpeed   Range  \
# 0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h  450 km
# 1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h  270 km
# 2    Polestar                               2   4.7 sec  210 km/h  400 km
# 3         BMW                            iX3    6.8 sec  180 km/h  360 km
# 4       Honda                              e    9.5 sec  145 km/h  170 km
#
#   Efficiency FastCharge              RapidCharge        PowerTrain  \
# 0  161 Wh/km   940 km/h  Rapid charging possible   All Wheel Drive
# 1  167 Wh/km   250 km/h  Rapid charging possible  Rear Wheel Drive
# 2  181 Wh/km   620 km/h  Rapid charging possible   All Wheel Drive
# 3  206 Wh/km   560 km/h  Rapid charging possible  Rear Wheel Drive
# 4  168 Wh/km   190 km/h  Rapid charging possible  Rear Wheel Drive
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
df = df[df.FastCharge != '-']

# %%
unit1= "sec"
unit2="km/h"
unit3="km"
unit4="Wh/km"
unit5="km/h"
df.Accel=[sub.replace(unit1, "").strip() for sub in df.Accel]
df.TopSpeed=[sub.replace(unit2, "").strip() for sub in df.TopSpeed]
df.Range=[sub.replace(unit3, "").strip() for sub in df.Range]
df.Efficiency=[sub.replace(unit4, "").strip() for sub in df.Efficiency]
df.FastCharge=[sub.replace(unit5, "").strip() for sub in df.FastCharge]

df['Accel'] = pd.to_numeric(df['Accel'])
df['TopSpeed'] = pd.to_numeric(df['TopSpeed'])
df['Range'] = pd.to_numeric(df['Range'])
df['Efficiency'] = pd.to_numeric(df['Efficiency'])
df['FastCharge'] = pd.to_numeric(df['FastCharge'])

df.rename(columns={"Accel":"Accel_sec", "TopSpeed": "TopSpeed_km/h", "Range": "Ragne_km", "Efficiency":"Efficiency_wh/km", "FastCharge": "FastCharge_km/h"}, inplace=True)

# %%
df.iloc[57,:]
# Out:
# Brand                              Citroen
# Model                                 e-C4
# Accel_sec                               9.7
# TopSpeed_km/h                           150
# Ragne_km                                250
# Efficiency_wh/km                        180
# FastCharge_km/h                         380
# RapidCharge         Rapid charging possible
# PowerTrain                Front Wheel Drive
# PlugType                         Type 2 CCS
# BodyStyle                               SUV
# Segment                                   C
# Seats                                     5
# PriceEuro                             40000
# Name: 58, dtype: object

# %%
df.dropna()
# Out:
#            Brand                            Model  Accel_sec  TopSpeed_km/h  \
# 0         Tesla     Model 3 Long Range Dual Motor        4.6            233
# 1    Volkswagen                         ID.3 Pure       10.0            160
# 2      Polestar                                 2        4.7            210
# 3           BMW                              iX3         6.8            180
# 4         Honda                                e         9.5            145
# ..           ...                              ...        ...            ...
# 98       Nissan                       Ariya 63kWh        7.5            160
# 99         Audi     e-tron S Sportback 55 quattro        4.5            210
# 100      Nissan               Ariya e-4ORCE 63kWh        5.9            200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance        5.1            200
# 102       Byton                 M-Byte 95 kWh 2WD        7.5            190
#
# ...

# %%
df['RapidCharge'].nunique()
# Out:
# 1

# %%
df['PowerTrain'].unique()
# Out:
# array(['All Wheel Drive', 'Rear Wheel Drive', 'Front Wheel Drive'],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_1 = df.loc[df['PriceEuro'] <= 50000]
df_2 = df.loc[df['PriceEuro'] > 50000]
t1 = 'Less than 50,000 Euros' 
t2 = 'More than 50,000 Euros'

# %%
def power_train(dataframe): 
    sns.countplot(x= dataframe['PowerTrain'])
    plt.title('Count Plot of Powertrain', fontsize = 20)
    plt.xlabel('Power Train', fontsize = 15)
    plt.ylabel('Count', fontsize = 15)

# %%
power_train(df)

# %%
def bodystyle(dataframe):
    plt.figure(figsize=(10, 5))
    sns.countplot(x= 'BodyStyle', data= dataframe, hue='PowerTrain')
    plt.title('Count plot of Body Style', fontsize= 20)
    plt.xlabel('Body Style', fontsize= 15)
    plt.ylabel('Count', fontsize= 15)
    plt.show()

# %%
bodystyle(df)

# %%
def range_price(dataframe, text):
  fig = plt.figure(figsize=(20,5))
  ax1 = plt.subplot()
  ax1.bar(dataframe['Brand'], dataframe['Ragne_km'],label= 'Range (Km)', color= 'steelblue')
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1.1))
  ax2 = ax1.twinx()
  ax2.scatter(dataframe['Brand'], dataframe['PriceEuro'], label= 'Price', color = 'black')
  plt.title('''RANGE (Km) vs PRICE (Euros)of EV's costing {}'''.format(text), fontsize= 20)
  ax1.set_xlabel('Models', size = 20)
  ax1.set_ylabel('Range (Km)', color = 'steelblue', size = 20)
  ax2.set_ylabel('Price (Euros)', color= 'black', size= 20)
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1))
  ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')
  plt.show()

# %%
range_price(df_1, t1)
range_price(df_2, t2)
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_15188\3593692371.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_15188\3593692371.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')

# %%
def range_efficiency(dataframe, text):
  fig = plt.figure(figsize=(20,5))
  ax1 = plt.subplot()
  ax1.bar(dataframe['Brand'], dataframe['Ragne_km'],label= 'Range (Km)', color= 'darkseagreen')
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1.1))
  ax2 = ax1.twinx()
  ax2.scatter(dataframe['Brand'], dataframe['Efficiency_wh/km'], label= 'Price', color = 'black')
  plt.title('''RANGE (Km) vs Efficiency (Wh/km)of EV's costing {}'''.format(text), fontsize= 20)
  ax1.set_xlabel('Models', size = 20)
  ax1.set_ylabel('Range (Km)', color = 'darkseagreen', size = 20)
  ax2.set_ylabel('Efficiency (Wh/Km)', color= 'black', size= 20)
  plt.legend(loc= 'upper left', bbox_to_anchor = (0, 1))
  ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')
  plt.show()

# %%
# range vs efficiency
range_efficiency(df_1, t1)
range_efficiency(df_2, t2)
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_15188\1764269984.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_15188\1764269984.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_1['Brand'], rotation = 'vertical')
